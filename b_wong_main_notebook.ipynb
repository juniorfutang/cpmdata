# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
root_path = '/gdrive/MyDrive/QPM/HeLa_cells_48-hour_run/'

# %%
root_path
# Out:
# '/gdrive/MyDrive/QPM/HeLa_cells_48-hour_run/'

# %%
test_im = plt.imread('/content/phase38.tif')

# %%
fig, ax = plt.subplots(ncols=1, figsize=(20,20))
ax.imshow(test_im, cmap='gray')
ax.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
img_seg=seg.slic(test_im, n_segments=69420)

# %%
fig, ax = plt.subplots(ncols=1, figsize=(20,20))
ax.imshow(img_seg, cmap='gray')
ax.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
im_seg2 = seg.felzenszwalb(test_im)

# %%
fig, ax = plt.subplots(ncols=1, figsize=(20,20))
ax.imshow(im_seg2, cmap='gray')
ax.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
from skimage import img_as_float
im_float = img_as_float(test_im)

# %%
im_binar = im_float > 0.15

# %%
fig, ax = plt.subplots(ncols=2, figsize=(40,20))
ax[0].imshow(im_binar, cmap='gray')
ax[1].imshow(test_im, cmap='gray')


for axi in ax:
 axi.axis('off')

# %%
im_binar
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])
