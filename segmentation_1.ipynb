# %% [markdown]
# <a href="https://colab.research.google.com/github/juniorfutang/cpmdata/blob/Thomas/segmentation_1" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
myim = plt.imread('drive/MyDrive/bgremovedphase/bgremovedphase/phase38.tif')
fig, ax = plt.subplots(figsize=(10,10));
ax.imshow(myim, cmap='gray');
ax.axis('off');

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(myim.ravel(), bins=32, range=[0, 256])
ax.set_xlim(0, 256);

# %%
def image_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 14))
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax

myim_segmented = myim > 1000
image_show(myim_segmented);
